# %%
import sys,os,imageio,lpips
root = '/home/youngsun/documents/mvs/mvsnerf'
os.chdir(root)
sys.path.append(root)

from opt import config_parser
from data import dataset_dict
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt


# models
from models import *
from renderer import *
from data.ray_utils import get_rays

from tqdm import tqdm


from skimage.metrics import structural_similarity

# pytorch-lightning
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning import LightningModule, Trainer, loggers


from data.ray_utils import ray_marcher

# %load_ext autoreload
# %autoreload 2

torch.cuda.set_device(0)
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
def decode_batch(batch):
    rays = batch['rays']  # (B, 8)
    rgbs = batch['rgbs']  # (B, 3)
    return rays, rgbs

def unpreprocess(data, shape=(1,1,3,1,1)):
    # to unnormalize image for visualization
    # data N V C H W
    device = data.device
    mean = torch.tensor([-0.485 / 0.229, -0.456 / 0.224, -0.406 / 0.225]).view(*shape).to(device)
    std = torch.tensor([1 / 0.229, 1 / 0.224, 1 / 0.225]).view(*shape).to(device)

    return (data - mean) / std

def read_depth(filename):
    depth_h = np.array(read_pfm(filename)[0], dtype=np.float32) # (800, 800)
    depth_h = cv2.resize(depth_h, None, fx=0.5, fy=0.5,
                       interpolation=cv2.INTER_NEAREST)  # (600, 800)
    depth_h = depth_h[44:556, 80:720]  # (512, 640)
#     depth = cv2.resize(depth_h, None, fx=0.5, fy=0.5,interpolation=cv2.INTER_NEAREST)#!!!!!!!!!!!!!!!!!!!!!!!!!
    mask = depth>0
    return depth_h,mask

loss_fn_vgg = lpips.LPIPS(net='vgg') 
mse2psnr = lambda x : -10. * np.log(x) / np.log(10.)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /opt/conda/envs/mvsnerf/lib/python3.8/site-packages/lpips/weights/v0.1/vgg.pth

# %% [markdown]
# # quantity evauation

# %%
import sys,os,imageio,lpips,cv2,torch,glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity

# %%
loss_fn_vgg = lpips.LPIPS(net='vgg') 
mse2psnr = lambda x : -10. * np.log(x) / np.log(10.)



def acc_threshold(abs_err, threshold):
    """
    computes the percentage of pixels whose depth error is less than @threshold
    """
    acc_mask = abs_err < threshold
    return  acc_mask.astype('float') if type(abs_err) is np.ndarray else acc_mask.float()
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /opt/conda/envs/mvsnerf/lib/python3.8/site-packages/lpips/weights/v0.1/vgg.pth

# %%
from torch.profiler import profile, record_function, ProfilerActivity

# %% [markdown]
# # DTU no fine tuning

# %% [markdown]
# ## rendering novel views with nearest 3 views

# %%
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
depth_acc = {}
eval_metric = [0.1,0.05,0.01]
depth_acc[f'abs_err'],depth_acc[f'acc_l_{eval_metric[0]}'],depth_acc[f'acc_l_{eval_metric[1]}'],depth_acc[f'acc_l_{eval_metric[2]}'] = {},{},{},{}


    

for i_scene, scene in enumerate([1]):#,8,21,103,114

    psnr,ssim,LPIPS_vgg = [],[],[]
    cmd = f'--datadir data/mvs_training/dtu/scan{scene}  \
     --dataset_name dtu_ft  \
     --net_type v0 --ckpt ./ckpts/mvsnerf-v0.tar '

    args = config_parser(cmd.split())
    args.use_viewdirs = True

    args.N_samples = 128
    args.feat_dim =  8+12

    # create models
    if 0==i_scene:
        render_kwargs_train, render_kwargs_test, start, grad_vars = create_nerf_mvs(args, use_mvs=True, dir_embedder=False, pts_embedder=True)
        filter_keys(render_kwargs_train)

        MVSNet = render_kwargs_train['network_mvs']
        render_kwargs_train.pop('network_mvs')


    datadir = args.datadir
    datatype = 'train'
    pad = 16
    args.chunk = 5120


    print('============> rendering dataset <===================')
    dataset_train = dataset_dict[args.dataset_name](args, split='train')
    dataset_val = dataset_dict[args.dataset_name](args, split='val')
    val_idx = dataset_val.img_idx

    save_as_image = True
    save_dir = f'results/test_dtu'
    os.makedirs(save_dir, exist_ok=True)
    MVSNet.train()
    MVSNet = MVSNet.cuda()


    with torch.no_grad():

        try:
            tqdm._instances.clear() 
        except Exception:     
            pass

        with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:

            for i, batch in enumerate(tqdm(dataset_val)):
                torch.cuda.empty_cache()

                rays, img = decode_batch(batch)
                rays = rays.squeeze().to(device)  # (H*W, 3)
                img = img.squeeze().cpu().numpy()  # (H, W, 3)
                depth = batch['depth'].squeeze().numpy()  # (H, W)

                # find nearest image idx from training views
                positions = dataset_train.poses[:,:3,3]
                dis = np.sum(np.abs(positions - dataset_val.poses[[i],:3,3]), axis=-1)
                pair_idx = np.argsort(dis)[:3]
                pair_idx = [dataset_train.img_idx[item] for item in pair_idx]

                imgs_source, proj_mats, near_far_source, pose_source = dataset_train.read_source_views(pair_idx=pair_idx,device=device)

                ###############################################
                with record_function("Neural Volume Encoding"):
                    volume_feature, _, _ = MVSNet(imgs_source, proj_mats, near_far_source, pad=pad)
                imgs_source = unpreprocess(imgs_source)

                N_rays_all = rays.shape[0]
                rgb_rays, depth_rays_preds = [],[]
                for chunk_idx in range(N_rays_all//args.chunk + int(N_rays_all%args.chunk>0)):

                    xyz_coarse_sampled, rays_o, rays_d, z_vals = ray_marcher(rays[chunk_idx*args.chunk:(chunk_idx+1)*args.chunk],
                                                        N_samples=args.N_samples)

                    # Converting world coordinate to ndc coordinate
                    H, W = img.shape[:2]
                    inv_scale = torch.tensor([W - 1, H - 1]).to(device)
                    w2c_ref, intrinsic_ref = pose_source['w2cs'][0], pose_source['intrinsics'][0].clone()
                    xyz_NDC = get_ndc_coordinate(w2c_ref, intrinsic_ref, xyz_coarse_sampled, inv_scale,
                                                 near=near_far_source[0], far=near_far_source[1], pad=pad*args.imgScale_test)


                    # rendering
                    ###############################################
                    with record_function("NeRF and Volume Rendering"):
                        rgb, disp, acc, depth_pred, alpha, extras = rendering(args, pose_source, xyz_coarse_sampled,
                                                                               xyz_NDC, z_vals, rays_o, rays_d,
                                                                               volume_feature,imgs_source, **render_kwargs_train)


                    rgb, depth_pred = torch.clamp(rgb.cpu(),0,1.0).numpy(), depth_pred.cpu().numpy()
                    rgb_rays.append(rgb)
                    depth_rays_preds.append(depth_pred)


                depth_rays_preds = np.concatenate(depth_rays_preds).reshape(H, W)

                depth_gt, _ =  read_depth(f'data/mvs_training/dtu/Depths/scan{scene}/depth_map_{val_idx[i]:04d}.pfm')

                mask_gt = depth_gt>0
                abs_err = abs_error(depth_rays_preds, depth_gt/200, mask_gt)

                eval_metric = [0.01,0.05, 0.1]
                depth_acc[f'abs_err'][f'{scene}'] = np.mean(abs_err)
                depth_acc[f'acc_l_{eval_metric[0]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[0]).mean()
                depth_acc[f'acc_l_{eval_metric[1]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[1]).mean()
                depth_acc[f'acc_l_{eval_metric[2]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[2]).mean()


                depth_rays_preds, _ = visualize_depth_numpy(depth_rays_preds, near_far_source)

                rgb_rays = np.concatenate(rgb_rays).reshape(H, W, 3)
                img_vis = np.concatenate((img*255,rgb_rays*255,depth_rays_preds),axis=1)

                if save_as_image:
                    imageio.imwrite(f'{save_dir}/scan{scene}_{val_idx[i]:03d}.png', img_vis.astype('uint8'))
                else:
                    rgbs.append(img_vis.astype('uint8'))

                # quantity
                # mask background since they are outside the far boundle
                mask = depth==0
                imageio.imwrite(f'{save_dir}/scan{scene}_{val_idx[i]:03d}_mask.png', mask.astype('uint8')*255)
                rgb_rays[mask],img[mask] = 0.0,0.0
                psnr.append( mse2psnr(np.mean((rgb_rays[~mask]-img[~mask])**2)))
                ssim.append( structural_similarity(rgb_rays, img, multichannel=True))

                img_tensor = torch.from_numpy(rgb_rays)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
                img_gt_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0
                LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

            print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
            psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)


    if not save_as_image:
        imageio.mimwrite(f'{save_dir}/{scene}_spiral.mp4', np.stack(rgbs), fps=20, quality=10)
        
print(prof.key_averages().table(sort_by="self_cuda_time_total", row_limit=2))

a = np.mean(list(depth_acc['abs_err'].values()))
b = np.mean(list(depth_acc[f'acc_l_{eval_metric[0]}'].values()))
c = np.mean(list(depth_acc[f'acc_l_{eval_metric[1]}'].values()))
d = np.mean(list(depth_acc[f'acc_l_{eval_metric[2]}'].values()))
print(f'============> abs_err: {a} <=================')
print(f'============> acc_l_{eval_metric[0]}: {b} <=================')
print(f'============> acc_l_{eval_metric[1]}: {c} <=================')
print(f'============> acc_l_{eval_metric[2]}: {d} <=================')
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')
# Out:
# Found ckpts ['./ckpts/mvsnerf-v0.tar']
# Reloading from ./ckpts/mvsnerf-v0.tar
# ============> rendering dataset <===================
# ==> image down scale: 1.0
# ===> training index: [25, 21, 33, 22, 14, 15, 26, 30, 31, 35, 34, 43, 46, 29, 16, 36]
# /opt/conda/envs/mvsnerf/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ==> image down scale: 1.0
# ===> valing index: [32, 24, 23, 44]
#   0%|                                                               | 0/4 [00:00<?, ?it/s]/tmp/ipykernel_21894/3055226584.py:137: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   ssim.append( structural_similarity(rgb_rays, img, multichannel=True))
# 100%|███████████████████████████████████████████████████████| 4/4 [00:19<00:00,  4.90s/it]
# =====> scene: 1 mean psnr 26.786920130245747 ssim: 0.9354719519615173 lpips: 0.15642568841576576
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                aten::mm         2.04%     290.795ms         2.75%     391.194ms      23.877us        2.682s        26.84%        2.682s     163.683us         16384
#                                               aten::mul         0.80%     113.303ms         1.23%     174.601ms      12.397us        1.942s        19.44%        1.942s     137.909us         14084
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 14.224s
# Self CUDA time total: 9.991s
#
# ============> abs_err: 0.01856994815170765 <=================
# ============> acc_l_0.01: 0.8148368127310122 <=================
# ============> acc_l_0.05: 0.907801279187917 <=================
# ============> acc_l_0.1: 0.9515616793391026 <=================
# =====> all mean psnr 26.786920130245747 ssim: 0.9354719519615173 lpips: 0.15642568841576576

# %%
print(prof.key_averages().table(sort_by="self_cpu_time_total"))
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                   cudaStreamSynchronize        53.61%        7.626s        53.61%        7.626s       4.863ms       0.000us         0.00%       0.000us       0.000us          1568
#                                aten::mkldnn_convolution        20.24%        2.880s        20.26%        2.881s      23.236ms       0.000us         0.00%       0.000us       0.000us           124
#                               NeRF and Volume Rendering         4.50%     640.746ms        70.15%        9.979s      38.980ms       0.000us         0.00%        9.481s      37.034ms           256
#                                        cudaLaunchKernel         2.93%     416.598ms         2.93%     416.598ms       4.635us       0.000us         0.00%       0.000us       0.000us         89872
#                                                aten::mm         2.04%     290.795ms         2.75%     391.194ms      23.877us        2.682s        26.84%        2.682s     163.683us         16384
#                                         aten::clamp_min         1.68%     238.502ms         3.37%     479.073ms      23.274us        1.347s        13.48%        2.694s     130.885us         20584
#                                            aten::linear         1.00%     142.684ms         6.62%     942.209ms      66.918us       0.000us         0.00%        4.460s     316.789us         14080
#                                               aten::pow         0.96%     136.678ms         1.04%     147.841ms       1.945ms      19.870ms         0.20%      19.870ms     261.447us            76
#                           aten::max_pool2d_with_indices         0.94%     133.463ms         0.94%     133.463ms       4.171ms       0.000us         0.00%       0.000us       0.000us            32
#                                               aten::div         0.89%     126.675ms         1.04%     147.403ms      32.611us      48.188ms         0.48%      48.188ms      10.661us          4520
#                                               aten::mul         0.80%     113.303ms         1.23%     174.601ms      12.397us        1.942s        19.44%        1.942s     137.909us         14084
#                                            aten::matmul         0.79%     112.472ms         4.43%     630.293ms      38.451us       0.000us         0.00%        2.836s     172.997us         16392
#                                               aten::sub         0.69%      97.610ms         0.80%     113.213ms      35.291us      44.056ms         0.44%      44.056ms      13.733us          3208
#                                              aten::add_         0.68%      97.011ms         1.09%     154.972ms      10.880us        1.781s        17.82%        1.781s     125.004us         14244
#                                             aten::copy_         0.55%      78.248ms        54.81%        7.796s     735.435us     314.373ms         3.15%     314.373ms      29.658us         10600
#                                             aten::slice         0.54%      76.724ms         0.64%      90.818ms       3.415us       0.000us         0.00%       0.000us       0.000us         26592
#                                              aten::_cat         0.46%      64.941ms         0.93%     132.278ms      21.460us        1.230s        12.31%        1.230s     199.561us          6164
#                                               aten::sum         0.45%      64.378ms         0.50%      70.643ms      64.929us      10.273ms         0.10%      10.273ms       9.442us          1088
#                                             aten::empty         0.45%      63.665ms         0.60%      85.138ms       3.640us       0.000us         0.00%       0.000us       0.000us         23392
#                                              cudaMalloc         0.39%      54.956ms         0.39%      54.956ms     981.357us       0.000us         0.00%       0.000us       0.000us            56
#                                           aten::resize_         0.38%      53.561ms         0.43%      60.588ms       3.600us       0.000us         0.00%       0.000us       0.000us         16828
#                                         cudaMemcpyAsync         0.38%      53.352ms         0.38%      53.352ms      18.499us       0.000us         0.00%       0.000us       0.000us          2884
#                                                cudaFree         0.36%      51.361ms         0.36%      51.361ms       1.317ms       0.000us         0.00%       0.000us       0.000us            39
#                                                 aten::t         0.32%      45.630ms         0.67%      95.434ms       5.825us       0.000us         0.00%       0.000us       0.000us         16384
#                                               aten::add         0.29%      41.320ms         0.52%      74.370ms      15.611us      81.135ms         0.81%      81.135ms      17.031us          4764
#                                         aten::transpose         0.26%      37.507ms         0.35%      49.804ms       3.040us       0.000us         0.00%       0.000us       0.000us         16384
#                                              aten::view         0.25%      36.108ms         0.25%      36.108ms       1.204us       0.000us         0.00%       0.000us       0.000us         29996
#                                        aten::as_strided         0.25%      35.316ms         0.25%      35.699ms       0.597us       0.000us         0.00%       0.000us       0.000us         59804
#                                              aten::relu         0.24%      34.403ms         1.70%     242.045ms      23.637us       0.000us         0.00%        1.347s     131.550us         10240
#                                      aten::_unsafe_view         0.20%      28.855ms         0.29%      40.800ms       2.894us       0.000us         0.00%       0.000us       0.000us         14096
#                                            aten::select         0.19%      27.348ms         0.23%      32.090ms       3.350us       0.000us         0.00%       0.000us       0.000us          9580
#                                 aten::cudnn_convolution         0.19%      26.827ms         0.25%      35.404ms     553.188us     185.071ms         1.85%     185.071ms       2.892ms            64
#                                               aten::cat         0.14%      19.890ms         1.07%     152.168ms      24.687us       0.000us         0.00%        1.230s     199.561us          6164
#                                     aten::empty_strided         0.13%      18.305ms         0.13%      18.712ms       4.883us       0.000us         0.00%       0.000us       0.000us          3832
#                                              InPlaceABN         0.13%      18.097ms         0.21%      30.424ms     422.556us      69.490ms         0.70%      71.037ms     986.625us            72
# cudaOccupancyMaxActiveBlocksPerMultiprocessorWithFla...         0.12%      16.955ms         0.12%      16.955ms       0.561us       0.000us         0.00%       0.000us       0.000us         30240
#                                             aten::clone         0.12%      16.670ms         0.69%      98.446ms      25.268us       0.000us         0.00%     158.364ms      40.648us          3896
#                                          aten::_to_copy         0.10%      14.853ms        54.25%        7.717s       3.043ms       0.000us         0.00%      28.690ms      11.313us          2536
#                                         aten::unsqueeze         0.08%      11.341ms         0.10%      13.648ms       3.717us       0.000us         0.00%       0.000us       0.000us          3672
#                                           aten::sigmoid         0.07%      10.138ms         0.11%      15.530ms      12.133us       3.915ms         0.04%       3.915ms       3.059us          1280
#                                        aten::max_pool2d         0.06%       9.115ms         1.00%     142.578ms       4.456ms       0.000us         0.00%       0.000us       0.000us            32
#                                                aten::gt         0.06%       8.810ms         0.09%      12.550ms      16.173us       7.952ms         0.08%       7.952ms      10.247us           776
#                                  Neural Volume Encoding         0.06%       8.611ms         0.96%     136.233ms      34.058ms       0.000us         0.00%     377.829ms      94.457ms             4
#                                           aten::reshape         0.06%       8.362ms         0.11%      15.403ms       4.255us       0.000us         0.00%      24.000us       0.007us          3620
#                                        aten::empty_like         0.06%       7.971ms         0.15%      21.564ms       6.903us       0.000us         0.00%       0.000us       0.000us          3124
#                                  aten::split_with_sizes         0.06%       7.824ms         0.16%      22.712ms      17.744us       0.000us         0.00%       0.000us       0.000us          1280
#                                                aten::lt         0.05%       7.202ms         0.08%      10.678ms      13.760us       8.125ms         0.08%       8.125ms      10.470us           776
#                                    aten::_reshape_alias         0.05%       6.833ms         0.05%       6.833ms       1.892us       0.000us         0.00%       0.000us       0.000us          3612
#                                                aten::to         0.04%       6.357ms        54.30%        7.723s       1.954ms       0.000us         0.00%      28.690ms       7.260us          3952
#                                            aten::narrow         0.04%       6.276ms         0.11%      14.978ms       3.880us       0.000us         0.00%       0.000us       0.000us          3860
#                                   aten::grid_sampler_2d         0.04%       5.891ms         0.09%      12.558ms      16.352us      31.823ms         0.32%      31.823ms      41.436us           768
#                                        aten::reciprocal         0.04%       5.821ms         0.06%       8.857ms      11.473us       1.629ms         0.02%       1.629ms       2.110us           772
#                                        aten::contiguous         0.04%       5.544ms         0.54%      77.463ms      27.161us       0.000us         0.00%     156.292ms      54.801us          2852
#                                              aten::norm         0.03%       4.171ms         0.04%       6.210ms      24.258us       1.024ms         0.01%       1.024ms       4.000us           256
#                                             aten::fill_         0.03%       4.049ms         0.04%       5.992ms       8.917us     677.000us         0.01%     677.000us       1.007us           672
#                                              aten::rsub         0.03%       4.018ms         0.11%      15.624ms      20.238us       0.000us         0.00%       2.053ms       2.659us           772
#                                      aten::grid_sampler         0.03%       3.948ms         0.21%      29.342ms      28.213us       0.000us         0.00%      87.426ms      84.063us          1040
#                                          aten::_softmax         0.02%       3.316ms         0.08%      11.719ms      45.777us       1.295ms         0.01%       5.934ms      23.180us           256
#                                           aten::permute         0.02%       3.296ms         0.03%       3.935ms       3.644us       0.000us         0.00%       0.000us       0.000us          1080
#                                             aten::clamp         0.02%       3.113ms         0.02%       3.113ms      12.160us       0.000us         0.00%       0.000us       0.000us           256
#                                           aten::cumprod         0.02%       3.031ms         0.03%       4.415ms      17.246us       2.678ms         0.03%       2.678ms      10.461us           256
#                                            aten::expand         0.02%       3.029ms         0.03%       3.581ms       4.164us       0.000us         0.00%       0.000us       0.000us           860
#                                          aten::linspace         0.02%       2.875ms         0.07%       9.385ms      17.002us     309.000us         0.00%     618.000us       1.120us           552
#                                               aten::neg         0.02%       2.722ms         0.03%       4.048ms      15.812us       4.696ms         0.05%       4.696ms      18.344us           256
#                                    aten::frobenius_norm         0.02%       2.639ms         0.10%      14.020ms      54.766us       0.000us         0.00%       1.545ms       6.035us           256
#                                               aten::sin         0.02%       2.604ms         0.03%       4.050ms      15.820us      48.408ms         0.48%      48.408ms     189.094us           256
#                                   aten::grid_sampler_3d         0.02%       2.437ms         0.03%       4.881ms      19.066us      45.786ms         0.46%      45.786ms     178.852us           256
#                                               aten::exp         0.02%       2.373ms         0.03%       3.618ms      14.133us       1.027ms         0.01%       1.027ms       4.012us           256
#                                      aten::_convolution         0.02%       2.342ms        20.55%        2.923s      14.617ms       0.000us         0.00%     201.089ms       1.005ms           200
#                                           aten::maximum         0.02%       2.296ms         0.02%       3.515ms      13.730us     328.000us         0.00%     328.000us       1.281us           256
#                                               aten::cos         0.02%       2.136ms         0.02%       3.150ms      12.305us      48.417ms         0.48%      48.417ms     189.129us           256
#                                              aten::sqrt         0.01%       1.950ms         0.01%       1.950ms      48.750us       0.000us         0.00%       0.000us       0.000us            40
#                                       aten::convolution         0.01%       1.630ms        20.56%        2.925s      14.625ms       0.000us         0.00%     201.089ms       1.005ms           200
#                                              aten::ones         0.01%       1.353ms         0.06%       8.672ms      33.354us       0.000us         0.00%     226.000us       0.869us           260
#                                            aten::unbind         0.01%       1.276ms         0.02%       2.577ms       9.616us       0.000us         0.00%       0.000us       0.000us           268
#                                             aten::zeros         0.01%       1.212ms         0.01%       1.739ms       6.688us       0.000us         0.00%       0.000us       0.000us           260
#                                            aten::conv2d         0.01%       1.144ms        20.50%        2.916s      18.225ms       0.000us         0.00%       5.419ms      33.869us           160
#                                         aten::ones_like         0.01%       1.088ms         0.04%       6.316ms      23.924us       0.000us         0.00%     292.000us       1.106us           264
#                       aten::cudnn_convolution_transpose         0.01%     997.000us         0.01%       1.223ms     101.917us      15.937ms         0.16%      15.937ms       1.328ms            12
#                                           aten::squeeze         0.01%     951.000us         0.01%       1.079ms       4.026us       0.000us         0.00%       0.000us       0.000us           268
#                                              aten::mul_         0.01%     890.000us         0.01%       1.466ms      10.181us     288.000us         0.00%     288.000us       2.000us           144
#                                           aten::detach_         0.01%     856.000us         0.01%       1.169ms       2.248us       0.000us         0.00%       0.000us       0.000us           520
#                                             aten::relu_         0.01%     834.000us         0.89%     126.823ms       1.219ms       0.000us         0.00%       0.000us       0.000us           104
#                                           aten::softmax         0.01%     829.000us         0.09%      12.548ms      49.016us       0.000us         0.00%       5.934ms      23.180us           256
#                                        aten::clamp_min_         0.00%     700.000us         0.89%     125.989ms       1.211ms       0.000us         0.00%       0.000us       0.000us           104
#                                               aten::bmm         0.00%     694.000us         0.01%       1.083ms     135.375us       3.621ms         0.04%       3.621ms     452.625us             8
#                                               aten::max         0.00%     651.000us         0.03%       4.159ms      16.246us       0.000us         0.00%     327.000us       1.277us           256
#                                              aten::div_         0.00%     632.000us         0.01%     897.000us      28.031us       0.000us         0.00%       0.000us       0.000us            32
#                                           cudaHostAlloc         0.00%     570.000us         0.00%     570.000us     570.000us       0.000us         0.00%       0.000us       0.000us             1
#                                              aten::sub_         0.00%     418.000us         0.00%     458.000us      22.900us      16.000us         0.00%      16.000us       0.800us            20
#                                              aten::full         0.00%     325.000us         0.01%       1.509ms      20.958us       0.000us         0.00%     140.000us       1.944us            72
#                                                 detach_         0.00%     313.000us         0.00%     394.000us       0.758us       0.000us         0.00%       0.000us       0.000us           520
#                                            aten::repeat         0.00%     303.000us         0.05%       7.590ms     379.500us       0.000us         0.00%       3.569ms     178.450us            20
#                                aten::cudnn_grid_sampler         0.00%     294.000us         0.06%       7.955ms     497.188us       8.530ms         0.09%       9.817ms     613.562us            16
#                                    cudaFuncSetAttribute         0.00%     261.000us         0.00%     261.000us       0.012us       0.000us         0.00%       0.000us       0.000us         21071
#                                       aten::as_strided_         0.00%     217.000us         0.00%     217.000us       1.750us       0.000us         0.00%       0.000us       0.000us           124
#                                 cudaGetDeviceProperties         0.00%     210.000us         0.00%     210.000us     210.000us       0.000us         0.00%       0.000us       0.000us             1
#                                              aten::mean         0.00%     207.000us         0.01%       1.335ms      66.750us       0.000us         0.00%       0.000us       0.000us            20
#                                             aten::zero_         0.00%     157.000us         0.00%     157.000us       0.604us       0.000us         0.00%       0.000us       0.000us           260
#                                            aten::unfold         0.00%     136.000us         0.00%     182.000us       2.395us       0.000us         0.00%       0.000us       0.000us            76
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 14.224s
# Self CUDA time total: 9.991s

# %%
prof.key_averages()
# Out:
# [<FunctionEventAvg key=aten::select self_cpu_time=27.348ms cpu_time=3.350us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::as_strided self_cpu_time=35.316ms cpu_time=0.597us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaFree self_cpu_time=51.361ms cpu_time=1.317ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::squeeze self_cpu_time=951.000us cpu_time=4.026us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::to self_cpu_time=6.357ms cpu_time=1.954ms  self_cuda_time=0.000us cuda_time=7.260us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_to_copy self_cpu_time=14.853ms cpu_time=3.043ms  self_cuda_time=0.000us cuda_time=11.313us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::empty_strided self_cpu_time=18.305ms cpu_time=4.883us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaStreamIsCapturing self_cpu_time=11.000us cpu_time=0.239us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaMalloc self_cpu_time=54.956ms cpu_time=981.357us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::copy_ self_cpu_time=78.248ms cpu_time=735.435us  self_cuda_time=314.373ms cuda_time=29.658us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaMemcpyAsync self_cpu_time=53.352ms cpu_time=18.499us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=Memcpy HtoD (Pageable -> Device) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=21.193ms cuda_time=20.069us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaStreamSynchronize self_cpu_time=7.626s cpu_time=4.863ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::view self_cpu_time=36.108ms cpu_time=1.204us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::permute self_cpu_time=3.296ms cpu_time=3.644us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::contiguous self_cpu_time=5.544ms cpu_time=27.161us  self_cuda_time=0.000us cuda_time=54.801us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::clone self_cpu_time=16.670ms cpu_time=25.268us  self_cuda_time=0.000us cuda_time=40.648us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::empty_like self_cpu_time=7.971ms cpu_time=6.903us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::empty self_cpu_time=63.665ms cpu_time=3.640us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::div self_cpu_time=126.675ms cpu_time=32.611us  self_cuda_time=48.188ms cuda_time=10.661us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::eq self_cpu_time=121.000us cpu_time=19.167us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::any self_cpu_time=116.000us cpu_time=11.667us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::fill_ self_cpu_time=4.049ms cpu_time=8.917us  self_cuda_time=677.000us cuda_time=1.007us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::is_nonzero self_cpu_time=43.000us cpu_time=7.750us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::item self_cpu_time=57.000us cpu_time=5.562us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_local_scalar_dense self_cpu_time=32.000us cpu_time=2.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sub_ self_cpu_time=418.000us cpu_time=22.900us  self_cuda_time=16.000us cuda_time=0.800us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::div_ self_cpu_time=632.000us cpu_time=28.031us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::stack self_cpu_time=80.000us cpu_time=335.167us  self_cuda_time=0.000us cuda_time=2.667us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::unsqueeze self_cpu_time=11.341ms cpu_time=3.717us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cat self_cpu_time=19.890ms cpu_time=24.687us  self_cuda_time=0.000us cuda_time=199.561us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_cat self_cpu_time=64.941ms cpu_time=21.460us  self_cuda_time=1.230s cuda_time=199.561us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::resize_ self_cpu_time=53.561ms cpu_time=3.600us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::narrow self_cpu_time=6.276ms cpu_time=3.880us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::slice self_cpu_time=76.724ms cpu_time=3.415us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::zeros self_cpu_time=1.212ms cpu_time=6.688us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::zero_ self_cpu_time=157.000us cpu_time=0.604us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=Neural Volume Encoding self_cpu_time=8.611ms cpu_time=34.058ms  self_cuda_time=0.000us cuda_time=94.457ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::reshape self_cpu_time=8.362ms cpu_time=4.255us  self_cuda_time=0.000us cuda_time=0.007us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_reshape_alias self_cpu_time=6.833ms cpu_time=1.892us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::conv2d self_cpu_time=1.144ms cpu_time=18.225ms  self_cuda_time=0.000us cuda_time=33.869us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::convolution self_cpu_time=1.630ms cpu_time=14.625ms  self_cuda_time=0.000us cuda_time=1.005ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_convolution self_cpu_time=2.342ms cpu_time=14.617ms  self_cuda_time=0.000us cuda_time=1.005ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cudnn_convolution self_cpu_time=26.827ms cpu_time=553.188us  self_cuda_time=185.071ms cuda_time=2.892ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaGetDeviceCount self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaDeviceGetAttribute self_cpu_time=1.000us cpu_time=0.031us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaDriverGetVersion self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaGetDeviceProperties self_cpu_time=210.000us cpu_time=210.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaStreamCreateWithFlags self_cpu_time=135.000us cpu_time=16.875us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaDeviceGetStreamPriorityRange self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaStreamCreateWithPriority self_cpu_time=5.000us cpu_time=1.250us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaMemsetAsync self_cpu_time=122.000us cpu_time=6.100us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=Memset (Device) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.269ms cuda_time=163.450us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaEventCreateWithFlags self_cpu_time=4.000us cpu_time=0.083us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaHostAlloc self_cpu_time=570.000us cpu_time=570.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaHostGetDevicePointer self_cpu_time=1.000us cpu_time=1.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaGetSymbolAddress self_cpu_time=1.000us cpu_time=1.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaEventRecord self_cpu_time=101.000us cpu_time=1.098us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaLaunchKernel self_cpu_time=416.598ms cpu_time=4.635us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cask_cudnn::computeOffsetsKernel<false, false>(cask_cudnn::ComputeOffsetsParams) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=43.000us cuda_time=3.583us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_scudnn_128x32_relu_small_nn_v1 self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.985ms cuda_time=165.417us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::add self_cpu_time=41.320ms cpu_time=15.611us  self_cuda_time=81.135ms cuda_time=17.031us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=InPlaceABN self_cpu_time=18.097ms cpu_time=422.556us  self_cuda_time=69.490ms cuda_time=986.625us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BUnaryFunctor<long, long, long, at::native::AddFunctor<long> >, at::detail::Array<char*, 2> >(int, at::native::BUnaryFunctor<long, long, long, at::native::AddFunctor<long> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=663.000us cuda_time=2.021us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::full self_cpu_time=325.000us cpu_time=20.958us  self_cuda_time=0.000us cuda_time=1.944us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::FillFunctor<long>, at::detail::Array<char*, 1> >(int, at::native::FillFunctor<long>, at::detail::Array<char*, 1>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=140.000us cuda_time=1.944us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void statistics_kernel<float, float, int>(at::GenericPackedTensorAccessor<float, 3ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=40.122ms cuda_time=557.250us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::copy_device_to_device(at::TensorIterator&, bool)::{lambda()#3}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, char*, at::native::memory::LoadWithCast<1>, at::detail::Array<char*, 2>::StoreWithCast>(int, at::native::copy_device_to_device(at::TensorIterator&, bool)::{lambda()#3}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, char*, at::native::memory::LoadWithCast<1>, at::detail::Array<char*, 2>::StoreWithCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=4.379ms cuda_time=5.164us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::mul_ self_cpu_time=890.000us cpu_time=10.181us  self_cuda_time=288.000us cuda_time=2.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2> >(int, at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=12.227ms cuda_time=4.667us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::mul self_cpu_time=113.303ms cpu_time=12.397us  self_cuda_time=1.942s cuda_time=137.909us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::add_ self_cpu_time=97.011ms cpu_time=10.880us  self_cuda_time=1.781s cuda_time=125.004us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BinaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 3> >(int, at::native::BinaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 3>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=42.525ms cuda_time=95.777us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BinaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BinaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=69.959ms cuda_time=29.345us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sub self_cpu_time=97.610ms cpu_time=35.291us  self_cuda_time=44.056ms cuda_time=13.733us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2> >(int, at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=30.027ms cuda_time=10.311us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=24.735ms cuda_time=13.129us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void forward_kernel<float, float, float, int, (Activation)0>(at::GenericPackedTensorAccessor<float, 3ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>, at::GenericPackedTensorAccessor<float, 1ul, at::RestrictPtrTraits, int>, float, float) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=29.368ms cuda_time=407.889us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void implicit_convolve_sgemm<float, float, 1024, 5, 5, 3, 3, 3, 1, false, false, true>(int, int, int, float const*, int, float*, float const*, kernel_conv_params, unsigned long long, int, float, float, int, float const*, float const*, bool, int, int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.076ms cuda_time=269.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cudnn::winograd::generateWinogradTilesKernel<0, float, float>(cudnn::winograd::GenerateWinogradTilesParams<float, float>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=46.000us cuda_time=2.875us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_scudnn_winograd_128x128_ldg1_ldg4_relu_tile148t_nt_v1 self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.440ms cuda_time=90.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaFuncGetAttributes self_cpu_time=28.000us cpu_time=1.750us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaFuncSetAttribute self_cpu_time=261.000us cpu_time=0.012us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cudnn::ops::nchwToNhwcKernel<float, float, float, false, true, (cudnnKernelDataType_t)2>(cudnn::ops::nchw2nhwc_params_t<float>, float const*, float*) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=8.456ms cuda_time=132.125us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cutlass_cudnn::Kernel<cutlass_tensorop_s1688fprop_optimized_tf32_128x64_16x6>(cutlass_tensorop_s1688fprop_optimized_tf32_128x64_16x6::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=476.000us cuda_time=119.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cudnn::ops::nhwcToNchwKernel<float, float, float, true, false, (cudnnKernelDataType_t)0>(cudnn::ops::nhwc2nchw_params_t<float>, float const*, float*) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=178.000us cuda_time=14.833us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BinaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BinaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.813s cuda_time=112.366us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::linspace self_cpu_time=2.875ms cpu_time=17.002us  self_cuda_time=309.000us cuda_time=1.120us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void (anonymous namespace)::elementwise_kernel_with_index<int, at::native::linspace_cuda_out(c10::Scalar const&, c10::Scalar const&, c10::optional<long>, at::Tensor&)::{lambda()#3}::operator()() const::{lambda()#4}::operator()() const::{lambda(long)#1}>(int, at::native::linspace_cuda_out(c10::Scalar const&, c10::Scalar const&, c10::optional<long>, at::Tensor&)::{lambda()#3}::operator()() const::{lambda()#4}::operator()() const::{lambda(long)#1}, function_traits<{lambda(long)#1}>::result_type*) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=309.000us cuda_time=1.120us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::rsub self_cpu_time=4.018ms cpu_time=20.238us  self_cuda_time=0.000us cuda_time=2.659us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::AUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2> >(int, at::native::AUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=2.053ms cuda_time=2.659us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::constant_pad_nd self_cpu_time=57.000us cpu_time=60.000us  self_cuda_time=0.000us cuda_time=13.500us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::FillFunctor<float>, at::detail::Array<char*, 1> >(int, at::native::FillFunctor<float>, at::detail::Array<char*, 1>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=537.000us cuda_time=1.974us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::copy_device_to_device(at::TensorIterator&, bool)::{lambda()#3}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, char*, at::native::memory::LoadWithoutCast, at::detail::Array<char*, 2>::StoreWithoutCast>(int, at::native::copy_device_to_device(at::TensorIterator&, bool)::{lambda()#3}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, char*, at::native::memory::LoadWithoutCast, at::detail::Array<char*, 2>::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=276.277ms cuda_time=41.186us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::upsample_bilinear2d self_cpu_time=102.000us cpu_time=805.500us  self_cuda_time=48.000us cuda_time=12.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::upsample_bilinear2d_out_frame<float, float>(int, float, float, bool, at::GenericPackedTensorAccessor<float, 4ul, at::DefaultPtrTraits, long>, at::GenericPackedTensorAccessor<float, 4ul, at::DefaultPtrTraits, long>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=48.000us cuda_time=12.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::expand self_cpu_time=3.029ms cpu_time=4.164us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::repeat self_cpu_time=303.000us cpu_time=379.500us  self_cuda_time=0.000us cuda_time=178.450us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::alias self_cpu_time=17.000us cpu_time=0.850us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::unfold self_cpu_time=136.000us cpu_time=2.395us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::expand_as self_cpu_time=34.000us cpu_time=5.500us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::pow self_cpu_time=136.678ms cpu_time=1.945ms  self_cuda_time=19.870ms cuda_time=261.447us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::result_type self_cpu_time=68.000us cpu_time=0.895us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::ones self_cpu_time=1.353ms cpu_time=33.354us  self_cuda_time=0.000us cuda_time=0.869us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::unbind self_cpu_time=1.276ms cpu_time=9.616us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::pow_tensor_scalar_kernel_impl<float, float>(at::TensorIteratorBase&, float)::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::pow_tensor_scalar_kernel_impl<float, float>(at::TensorIteratorBase&, float)::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=19.870ms cuda_time=1.242ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::meshgrid self_cpu_time=65.000us cpu_time=17.250us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_unsafe_view self_cpu_time=28.855ms cpu_time=2.894us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::ones_like self_cpu_time=1.088ms cpu_time=23.924us  self_cuda_time=0.000us cuda_time=1.106us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::matmul self_cpu_time=112.472ms cpu_time=38.451us  self_cuda_time=0.000us cuda_time=172.997us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::bmm self_cpu_time=694.000us cpu_time=135.375us  self_cuda_time=3.621ms cuda_time=452.625us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaOccupancyMaxActiveBlocksPerMultiprocessorWithFlags self_cpu_time=16.955ms cpu_time=0.561us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::CatArrayBatchedCopy<float, unsigned int, 3, 64, 64>(float*, at::native::(anonymous namespace)::CatArrInputTensorMetadata<float, unsigned int, 64, 64>, at::native::(anonymous namespace)::TensorSizeStride<unsigned int, 4u>, int, unsigned int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=835.906ms cuda_time=296.001us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::CatArrayBatchedCopy<float, unsigned int, 3, 128, 1>(float*, at::native::(anonymous namespace)::CatArrInputTensorMetadata<float, unsigned int, 128, 1>, at::native::(anonymous namespace)::TensorSizeStride<unsigned int, 4u>, int, unsigned int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=369.808ms cuda_time=179.868us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_sgemm_128x32_nn self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.621ms cuda_time=113.156us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::grid_sampler self_cpu_time=3.948ms cpu_time=28.213us  self_cuda_time=0.000us cuda_time=84.063us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cudnn_grid_sampler self_cpu_time=294.000us cpu_time=497.188us  self_cuda_time=8.530ms cuda_time=613.562us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=Memcpy DtoD (Device -> Device) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=9.491ms cuda_time=7.212us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::gt self_cpu_time=8.810ms cpu_time=16.173us  self_cuda_time=7.952ms cuda_time=10.247us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::lt self_cpu_time=7.202ms cpu_time=13.760us  self_cuda_time=8.125ms cuda_time=10.470us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cudnn::bilinear_sampler_fw_4d<float, float>(cudnnTensorStruct, float const*, float const*, cudnnTensorStruct, float*, int, cudnn::reduced_divisor, float, float) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=8.530ms cuda_time=533.125us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BUnaryFunctor<float, float, bool, at::native::CompareGTFunctor<float> >, at::detail::Array<char*, 2> >(int, at::native::BUnaryFunctor<float, float, bool, at::native::CompareGTFunctor<float> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=7.952ms cuda_time=10.247us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BUnaryFunctor<float, float, bool, at::native::CompareLTFunctor<float> >, at::detail::Array<char*, 2> >(int, at::native::BUnaryFunctor<float, float, bool, at::native::CompareLTFunctor<float> >, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=8.125ms cuda_time=10.470us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BinaryFunctor<bool, bool, bool, at::native::MulFunctor<bool> >, at::detail::Array<char*, 3> >(int, at::native::BinaryFunctor<bool, bool, bool, at::native::MulFunctor<bool> >, at::detail::Array<char*, 3>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=4.304ms cuda_time=5.490us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sum self_cpu_time=64.378ms cpu_time=64.929us  self_cuda_time=10.273ms cuda_time=9.442us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::reciprocal self_cpu_time=5.821ms cpu_time=11.473us  self_cuda_time=1.629ms cuda_time=2.110us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::conv3d self_cpu_time=89.000us cpu_time=318.929us  self_cuda_time=0.000us cuda_time=6.419ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::conv_transpose3d self_cpu_time=41.000us cpu_time=114.583us  self_cuda_time=0.000us cuda_time=1.328ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cudnn_convolution_transpose self_cpu_time=997.000us cpu_time=101.917us  self_cuda_time=15.937ms cuda_time=1.328ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::detach_ self_cpu_time=856.000us cpu_time=2.248us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=detach_ self_cpu_time=313.000us cpu_time=0.758us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::reduce_kernel<128, 4, at::native::ReduceOp<float, at::native::func_wrapper_t<float, at::native::sum_functor<float, float, float>::operator()(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4> >(at::native::ReduceOp<float, at::native::func_wrapper_t<float, at::native::sum_functor<float, float, float>::operator()(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=322.000us cuda_time=80.500us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::reciprocal_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::reciprocal_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.629ms cuda_time=2.110us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=sm80_xmma_fprop_implicit_gemm_tf32f32_tf32f32_f32_nhwckrsc_nchw_tilesize128x128x16_stage4_warpsize2x2x1_g1_tensor16x8x8_kernel self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=164.454ms cuda_time=8.223ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void implicit_convolveNd_sgemm<float, 3, 1024, 5, 5, 3, 3, 3, 1, false, false, true>(int, int, int, float const*, int, float*, float const*, kernel_convNd_params, unsigned long long, int, float, float, int, float const*, float const*, bool) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.154ms cuda_time=788.500us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=sm80_xmma_fprop_implicit_gemm_tf32f32_tf32f32_f32_nhwckrsc_nhwc_tilesize128x128x16_stage4_warpsize2x2x1_g1_tensor16x8x8_kernel self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=600.000us cuda_time=150.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void xmma_cudnn::gemm::kernel<xmma_cudnn::implicit_gemm::dgrad::Kernel_traits<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_a_t<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 16, false, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_base_a<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 16, xmma_cudnn::Row, 16, 128> >, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_c_t<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, 16, xmma_cudnn::Fragment_c<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, false>, false>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 4> >(xmma_cudnn::implicit_gemm::dgrad::Kernel_traits<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_a_t<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 16, false, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_base_a<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 16, xmma_cudnn::Row, 16, 128> >, xmma_cudnn::implicit_gemm::dgrad::Gmem_tile_c_t<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, 16, xmma_cudnn::Fragment_c<xmma_cudnn::Ampere_hmma_tf32_traits<unsigned int, float>, xmma_cudnn::Cta_tile<xmma_cudnn::Ampere, 128, 128, 16, 2, 2, 1, 1>, false>, false>, xmma_cudnn::implicit_gemm::Input_related<0, 0, 0, false>, 4>::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.520ms cuda_time=880.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cudnn::ops::setTensor5d_kernel<float, float, 8, 8, 8>(cudnnTensorStruct, float*, float) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.782ms cuda_time=222.750us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void convolveNd_dgrad_float_engine<float, 3, 512, 6, 5, 3, 3, 3, false>(int, int, int, float const*, int, float const*, int, float*, kernel_gradNd_params, unsigned long long, int, unsigned long long, int, float, int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=10.529ms cuda_time=1.316ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::t self_cpu_time=45.630ms cpu_time=5.825us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::transpose self_cpu_time=37.507ms cpu_time=3.040us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::mm self_cpu_time=290.795ms cpu_time=23.877us  self_cuda_time=2.682s cuda_time=163.683us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_sgemm_32x128_tn self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=234.091ms cuda_time=70.340us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithCast<2>, at::native::memory::StoreWithCast>(int, at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithCast<2>, at::native::memory::StoreWithCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=17.681ms cuda_time=17.267us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=16.582ms cuda_time=16.193us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, TrivialOffsetCalculator<1, unsigned int>, at::native::memory::LoadWithCast<1>, at::native::memory::StoreWithCast>(int, at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, TrivialOffsetCalculator<1, unsigned int>, at::native::memory::LoadWithCast<1>, at::native::memory::StoreWithCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=518.000us cuda_time=2.023us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, TrivialOffsetCalculator<1, unsigned int>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BUnaryFunctor<float, float, float, at::native::AddFunctor<float> >, at::detail::Array<char*, 2>, TrivialOffsetCalculator<1, unsigned int>, TrivialOffsetCalculator<1, unsigned int>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=780.000us cuda_time=1.523us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=NeRF and Volume Rendering self_cpu_time=640.746ms cpu_time=38.980ms  self_cuda_time=0.000us cuda_time=37.034ms input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::frobenius_norm self_cpu_time=2.639ms cpu_time=54.766us  self_cuda_time=0.000us cuda_time=6.035us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::norm self_cpu_time=4.171ms cpu_time=24.258us  self_cuda_time=1.024ms cuda_time=4.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::reduce_kernel<512, 1, at::native::ReduceOp<float, at::native::NormTwoOps<float, float>, unsigned int, float, 4> >(at::native::ReduceOp<float, at::native::NormTwoOps<float, float>, unsigned int, float, 4>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.024ms cuda_time=4.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cutlass::Kernel<cutlass_80_tensorop_s1688gemm_64x64_16x6_tn_align1>(cutlass_80_tensorop_s1688gemm_64x64_16x6_tn_align1::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.293ms cuda_time=5.051us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::grid_sampler_3d self_cpu_time=2.437ms cpu_time=19.066us  self_cuda_time=45.786ms cuda_time=178.852us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::grid_sampler_3d_kernel<float, int>(int, at::cuda::detail::TensorInfo<float, int>, at::cuda::detail::TensorInfo<float, int>, at::cuda::detail::TensorInfo<float, int>, at::native::detail::GridSamplerInterpolation, at::native::detail::GridSamplerPadding, bool) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=45.786ms cuda_time=178.852us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BUnaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=14.466ms cuda_time=18.836us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::grid_sampler_2d self_cpu_time=5.891ms cpu_time=16.352us  self_cuda_time=31.823ms cuda_time=41.436us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::grid_sampler_2d_kernel<float, int>(int, at::cuda::detail::TensorInfo<float, int>, at::cuda::detail::TensorInfo<float, int>, at::cuda::detail::TensorInfo<float, int>, at::native::detail::GridSamplerInterpolation, at::native::detail::GridSamplerPadding, bool) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=31.823ms cuda_time=41.436us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::BinaryFunctor<bool, bool, bool, at::native::MulFunctor<bool> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast>(int, at::native::BinaryFunctor<bool, bool, bool, at::native::MulFunctor<bool> >, at::detail::Array<char*, 3>, OffsetCalculator<2, unsigned int, false>, OffsetCalculator<1, unsigned int, false>, at::native::memory::LoadWithoutCast, at::native::memory::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.937ms cuda_time=5.126us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::CatArrayBatchedCopy<float, unsigned int, 4, 128, 1>(float*, at::native::(anonymous namespace)::CatArrInputTensorMetadata<float, unsigned int, 128, 1>, at::native::(anonymous namespace)::TensorSizeStride<unsigned int, 4u>, int, unsigned int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=21.085ms cuda_time=27.454us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sin self_cpu_time=2.604ms cpu_time=15.820us  self_cuda_time=48.408ms cuda_time=189.094us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cos self_cpu_time=2.136ms cpu_time=12.305us  self_cuda_time=48.417ms cuda_time=189.129us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::sin_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::sin_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=48.408ms cuda_time=189.094us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::split_with_sizes self_cpu_time=7.824ms cpu_time=17.744us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::linear self_cpu_time=142.684ms cpu_time=66.918us  self_cuda_time=0.000us cuda_time=316.789us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::cos_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::cos_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=48.417ms cuda_time=189.129us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::relu self_cpu_time=34.403ms cpu_time=23.637us  self_cuda_time=0.000us cuda_time=131.550us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::clamp_min self_cpu_time=238.502ms cpu_time=23.274us  self_cuda_time=1.347s cuda_time=130.885us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sigmoid self_cpu_time=10.138ms cpu_time=12.133us  self_cuda_time=3.915ms cuda_time=3.059us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cutlass::Kernel<cutlass_80_tensorop_s1688gemm_128x128_16x5_tn_align4>(cutlass_80_tensorop_s1688gemm_128x128_16x5_tn_align4::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.311s cuda_time=170.660us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_sgemm_128x64_tn self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=233.345ms cuda_time=182.301us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BinaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 3> >(int, at::native::BinaryFunctor<float, float, float, at::native::MulFunctor<float> >, at::detail::Array<char*, 3>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.842s cuda_time=232.165us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::(anonymous namespace)::clamp_min_scalar_kernel_impl(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::(anonymous namespace)::clamp_min_scalar_kernel_impl(at::TensorIterator&, c10::Scalar)::{lambda()#1}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.347s cuda_time=131.550us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cutlass::Kernel<cutlass_80_tensorop_s1688gemm_128x256_16x3_tn_align1>(cutlass_80_tensorop_s1688gemm_128x256_16x3_tn_align1::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=448.836ms cuda_time=350.653us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=ampere_sgemm_128x32_tt self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=170.004ms cuda_time=132.816us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void cutlass::Kernel<cutlass_80_tensorop_s1688gemm_64x256_16x4_tn_align1>(cutlass_80_tensorop_s1688gemm_64x256_16x4_tn_align1::Params) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=283.543ms cuda_time=221.518us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::sigmoid_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::sigmoid_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.915ms cuda_time=3.059us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::CatArrayBatchedCopy<float, unsigned int, 2, 64, 64>(float*, at::native::(anonymous namespace)::CatArrInputTensorMetadata<float, unsigned int, 64, 64>, at::native::(anonymous namespace)::TensorSizeStride<unsigned int, 4u>, int, unsigned int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.737ms cuda_time=6.785us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::softmax self_cpu_time=829.000us cpu_time=49.016us  self_cuda_time=0.000us cuda_time=23.180us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::_softmax self_cpu_time=3.316ms cpu_time=45.777us  self_cuda_time=1.295ms cuda_time=23.180us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void (anonymous namespace)::softmax_warp_forward<float, float, float, 7, false>(float*, float const*, int, int, int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.295ms cuda_time=5.059us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::neg self_cpu_time=2.722ms cpu_time=15.812us  self_cuda_time=4.696ms cuda_time=18.344us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::unrolled_elementwise_kernel<at::native::neg_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, char*, at::native::memory::LoadWithoutCast, at::detail::Array<char*, 2>::StoreWithoutCast>(int, at::native::neg_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#8}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>, OffsetCalculator<1, unsigned int, false>, char*, at::native::memory::LoadWithoutCast, at::detail::Array<char*, 2>::StoreWithoutCast) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=4.696ms cuda_time=18.344us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::exp self_cpu_time=2.373ms cpu_time=14.133us  self_cuda_time=1.027ms cuda_time=4.012us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::exp_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2> >(int, at::native::exp_kernel_cuda(at::TensorIteratorBase&)::{lambda()#1}::operator()() const::{lambda()#4}::operator()() const::{lambda(float)#1}, at::detail::Array<char*, 2>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.027ms cuda_time=4.012us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::(anonymous namespace)::CatArrayBatchedCopy<float, unsigned int, 2, 128, 1>(float*, at::native::(anonymous namespace)::CatArrInputTensorMetadata<float, unsigned int, 128, 1>, at::native::(anonymous namespace)::TensorSizeStride<unsigned int, 4u>, int, unsigned int) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=1.771ms cuda_time=6.918us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::cumprod self_cpu_time=3.031ms cpu_time=17.246us  self_cuda_time=2.678ms cuda_time=10.461us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=_ZN2at6native32tensor_kernel_scan_innermost_dimIfLi16ELi32ESt10multipliesIfEEENSt9enable_ifIXntsr3c1010is_complexIT_EE5valueEvE4typeEPS5_S8_jjS5_T2_ self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=2.678ms cuda_time=10.461us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::reduce_kernel<512, 1, at::native::ReduceOp<float, at::native::func_wrapper_t<float, at::native::sum_functor<float, float, float>::operator()(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4> >(at::native::ReduceOp<float, at::native::func_wrapper_t<float, at::native::sum_functor<float, float, float>::operator()(at::TensorIterator&)::{lambda(float, float)#1}>, unsigned int, float, 4>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=9.951ms cuda_time=9.718us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3> >(int, at::native::BinaryFunctor<float, float, float, at::native::DivFunctor<float> >, at::detail::Array<char*, 3>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=512.000us cuda_time=2.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::max self_cpu_time=651.000us cpu_time=16.246us  self_cuda_time=0.000us cuda_time=1.277us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::maximum self_cpu_time=2.296ms cpu_time=13.730us  self_cuda_time=328.000us cuda_time=1.281us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=void at::native::vectorized_elementwise_kernel<4, at::native::BinaryFunctor<float, float, float, at::native::maximum_kernel_cuda(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>, at::detail::Array<char*, 3> >(int, at::native::BinaryFunctor<float, float, float, at::native::maximum_kernel_cuda(at::TensorIteratorBase&)::{lambda()#2}::operator()() const::{lambda()#4}::operator()() const::{lambda(float, float)#1}>, at::detail::Array<char*, 3>) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=328.000us cuda_time=1.281us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=Memcpy DtoH (Device -> Pageable) self_cpu_time=0.000us cpu_time=0.000us  self_cuda_time=3.118ms cuda_time=6.090us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::clamp self_cpu_time=3.113ms cpu_time=12.160us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::mkldnn_convolution self_cpu_time=2.880s cpu_time=23.236ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::as_strided_ self_cpu_time=217.000us cpu_time=1.750us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::relu_ self_cpu_time=834.000us cpu_time=1.219ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::clamp_min_ self_cpu_time=700.000us cpu_time=1.211ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::max_pool2d self_cpu_time=9.115ms cpu_time=4.456ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::max_pool2d_with_indices self_cpu_time=133.463ms cpu_time=4.171ms  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::sqrt self_cpu_time=1.950ms cpu_time=48.750us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::dropout self_cpu_time=16.000us cpu_time=0.800us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=aten::mean self_cpu_time=207.000us cpu_time=66.750us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>,
#  <FunctionEventAvg key=cudaDeviceSynchronize self_cpu_time=13.000us cpu_time=13.000us  self_cuda_time=0.000us cuda_time=0.000us input_shapes= cpu_memory_usage=0 cuda_memory_usage=0>]

# %%
print(prof.key_averages().table())
# Out:
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                                    Name    Self CPU %      Self CPU   CPU total %     CPU total  CPU time avg     Self CUDA   Self CUDA %    CUDA total  CUDA time avg    # of Calls
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
#                                            aten::select         0.19%      27.348ms         0.23%      32.090ms       3.350us       0.000us         0.00%       0.000us       0.000us          9580
#                                        aten::as_strided         0.25%      35.316ms         0.25%      35.699ms       0.597us       0.000us         0.00%       0.000us       0.000us         59804
#                                                cudaFree         0.36%      51.361ms         0.36%      51.361ms       1.317ms       0.000us         0.00%       0.000us       0.000us            39
#                                           aten::squeeze         0.01%     951.000us         0.01%       1.079ms       4.026us       0.000us         0.00%       0.000us       0.000us           268
#                                                aten::to         0.04%       6.357ms        54.30%        7.723s       1.954ms       0.000us         0.00%      28.690ms       7.260us          3952
#                                          aten::_to_copy         0.10%      14.853ms        54.25%        7.717s       3.043ms       0.000us         0.00%      28.690ms      11.313us          2536
#                                     aten::empty_strided         0.13%      18.305ms         0.13%      18.712ms       4.883us       0.000us         0.00%       0.000us       0.000us          3832
#                                   cudaStreamIsCapturing         0.00%      11.000us         0.00%      11.000us       0.239us       0.000us         0.00%       0.000us       0.000us            46
#                                              cudaMalloc         0.39%      54.956ms         0.39%      54.956ms     981.357us       0.000us         0.00%       0.000us       0.000us            56
#                                             aten::copy_         0.55%      78.248ms        54.81%        7.796s     735.435us     314.373ms         3.15%     314.373ms      29.658us         10600
#                                         cudaMemcpyAsync         0.38%      53.352ms         0.38%      53.352ms      18.499us       0.000us         0.00%       0.000us       0.000us          2884
#                        Memcpy HtoD (Pageable -> Device)         0.00%       0.000us         0.00%       0.000us       0.000us      21.193ms         0.21%      21.193ms      20.069us          1056
#                                   cudaStreamSynchronize        53.61%        7.626s        53.61%        7.626s       4.863ms       0.000us         0.00%       0.000us       0.000us          1568
#                                              aten::view         0.25%      36.108ms         0.25%      36.108ms       1.204us       0.000us         0.00%       0.000us       0.000us         29996
#                                           aten::permute         0.02%       3.296ms         0.03%       3.935ms       3.644us       0.000us         0.00%       0.000us       0.000us          1080
#                                        aten::contiguous         0.04%       5.544ms         0.54%      77.463ms      27.161us       0.000us         0.00%     156.292ms      54.801us          2852
#                                             aten::clone         0.12%      16.670ms         0.69%      98.446ms      25.268us       0.000us         0.00%     158.364ms      40.648us          3896
#                                        aten::empty_like         0.06%       7.971ms         0.15%      21.564ms       6.903us       0.000us         0.00%       0.000us       0.000us          3124
#                                             aten::empty         0.45%      63.665ms         0.60%      85.138ms       3.640us       0.000us         0.00%       0.000us       0.000us         23392
#                                               aten::div         0.89%     126.675ms         1.04%     147.403ms      32.611us      48.188ms         0.48%      48.188ms      10.661us          4520
#                                                aten::eq         0.00%     121.000us         0.00%     230.000us      19.167us       0.000us         0.00%       0.000us       0.000us            12
#                                               aten::any         0.00%     116.000us         0.00%     140.000us      11.667us       0.000us         0.00%       0.000us       0.000us            12
#                                             aten::fill_         0.03%       4.049ms         0.04%       5.992ms       8.917us     677.000us         0.01%     677.000us       1.007us           672
#                                        aten::is_nonzero         0.00%      43.000us         0.00%      93.000us       7.750us       0.000us         0.00%       0.000us       0.000us            12
#                                              aten::item         0.00%      57.000us         0.00%      89.000us       5.562us       0.000us         0.00%       0.000us       0.000us            16
#                               aten::_local_scalar_dense         0.00%      32.000us         0.00%      32.000us       2.000us       0.000us         0.00%       0.000us       0.000us            16
#                                              aten::sub_         0.00%     418.000us         0.00%     458.000us      22.900us      16.000us         0.00%      16.000us       0.800us            20
#                                              aten::div_         0.00%     632.000us         0.01%     897.000us      28.031us       0.000us         0.00%       0.000us       0.000us            32
#                                             aten::stack         0.00%      80.000us         0.03%       4.022ms     335.167us       0.000us         0.00%      32.000us       2.667us            12
#                                         aten::unsqueeze         0.08%      11.341ms         0.10%      13.648ms       3.717us       0.000us         0.00%       0.000us       0.000us          3672
#                                               aten::cat         0.14%      19.890ms         1.07%     152.168ms      24.687us       0.000us         0.00%        1.230s     199.561us          6164
#                                              aten::_cat         0.46%      64.941ms         0.93%     132.278ms      21.460us        1.230s        12.31%        1.230s     199.561us          6164
#                                           aten::resize_         0.38%      53.561ms         0.43%      60.588ms       3.600us       0.000us         0.00%       0.000us       0.000us         16828
#                                            aten::narrow         0.04%       6.276ms         0.11%      14.978ms       3.880us       0.000us         0.00%       0.000us       0.000us          3860
#                                             aten::slice         0.54%      76.724ms         0.64%      90.818ms       3.415us       0.000us         0.00%       0.000us       0.000us         26592
#                                             aten::zeros         0.01%       1.212ms         0.01%       1.739ms       6.688us       0.000us         0.00%       0.000us       0.000us           260
#                                             aten::zero_         0.00%     157.000us         0.00%     157.000us       0.604us       0.000us         0.00%       0.000us       0.000us           260
#                                  Neural Volume Encoding         0.06%       8.611ms         0.96%     136.233ms      34.058ms       0.000us         0.00%     377.829ms      94.457ms             4
#                                           aten::reshape         0.06%       8.362ms         0.11%      15.403ms       4.255us       0.000us         0.00%      24.000us       0.007us          3620
#                                    aten::_reshape_alias         0.05%       6.833ms         0.05%       6.833ms       1.892us       0.000us         0.00%       0.000us       0.000us          3612
#                                            aten::conv2d         0.01%       1.144ms        20.50%        2.916s      18.225ms       0.000us         0.00%       5.419ms      33.869us           160
#                                       aten::convolution         0.01%       1.630ms        20.56%        2.925s      14.625ms       0.000us         0.00%     201.089ms       1.005ms           200
#                                      aten::_convolution         0.02%       2.342ms        20.55%        2.923s      14.617ms       0.000us         0.00%     201.089ms       1.005ms           200
#                                 aten::cudnn_convolution         0.19%      26.827ms         0.25%      35.404ms     553.188us     185.071ms         1.85%     185.071ms       2.892ms            64
#                                      cudaGetDeviceCount         0.00%       0.000us         0.00%       0.000us       0.000us       0.000us         0.00%       0.000us       0.000us             1
#                                  cudaDeviceGetAttribute         0.00%       1.000us         0.00%       1.000us       0.031us       0.000us         0.00%       0.000us       0.000us            32
#                                    cudaDriverGetVersion         0.00%       0.000us         0.00%       0.000us       0.000us       0.000us         0.00%       0.000us       0.000us             1
#                                 cudaGetDeviceProperties         0.00%     210.000us         0.00%     210.000us     210.000us       0.000us         0.00%       0.000us       0.000us             1
#                               cudaStreamCreateWithFlags         0.00%     135.000us         0.00%     135.000us      16.875us       0.000us         0.00%       0.000us       0.000us             8
#                        cudaDeviceGetStreamPriorityRange         0.00%       0.000us         0.00%       0.000us       0.000us       0.000us         0.00%       0.000us       0.000us             1
#                            cudaStreamCreateWithPriority         0.00%       5.000us         0.00%       5.000us       1.250us       0.000us         0.00%       0.000us       0.000us             4
#                                         cudaMemsetAsync         0.00%     122.000us         0.00%     122.000us       6.100us       0.000us         0.00%       0.000us       0.000us            20
#                                         Memset (Device)         0.00%       0.000us         0.00%       0.000us       0.000us       3.269ms         0.03%       3.269ms     163.450us            20
#                                cudaEventCreateWithFlags         0.00%       4.000us         0.00%       4.000us       0.083us       0.000us         0.00%       0.000us       0.000us            48
#                                           cudaHostAlloc         0.00%     570.000us         0.00%     570.000us     570.000us       0.000us         0.00%       0.000us       0.000us             1
#                                cudaHostGetDevicePointer         0.00%       1.000us         0.00%       1.000us       1.000us       0.000us         0.00%       0.000us       0.000us             1
#                                    cudaGetSymbolAddress         0.00%       1.000us         0.00%       1.000us       1.000us       0.000us         0.00%       0.000us       0.000us             1
#                                         cudaEventRecord         0.00%     101.000us         0.00%     101.000us       1.098us       0.000us         0.00%       0.000us       0.000us            92
#                                        cudaLaunchKernel         2.93%     416.598ms         2.93%     416.598ms       4.635us       0.000us         0.00%       0.000us       0.000us         89872
# void cask_cudnn::computeOffsetsKernel<false, false>(...         0.00%       0.000us         0.00%       0.000us       0.000us      43.000us         0.00%      43.000us       3.583us            12
#                   ampere_scudnn_128x32_relu_small_nn_v1         0.00%       0.000us         0.00%       0.000us       0.000us       1.985ms         0.02%       1.985ms     165.417us            12
#                                               aten::add         0.29%      41.320ms         0.52%      74.370ms      15.611us      81.135ms         0.81%      81.135ms      17.031us          4764
#                                              InPlaceABN         0.13%      18.097ms         0.21%      30.424ms     422.556us      69.490ms         0.70%      71.037ms     986.625us            72
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us     663.000us         0.01%     663.000us       2.021us           328
#                                              aten::full         0.00%     325.000us         0.01%       1.509ms      20.958us       0.000us         0.00%     140.000us       1.944us            72
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us     140.000us         0.00%     140.000us       1.944us            72
# void statistics_kernel<float, float, int>(at::Generi...         0.00%       0.000us         0.00%       0.000us       0.000us      40.122ms         0.40%      40.122ms     557.250us            72
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us       4.379ms         0.04%       4.379ms       5.164us           848
#                                              aten::mul_         0.01%     890.000us         0.01%       1.466ms      10.181us     288.000us         0.00%     288.000us       2.000us           144
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us      12.227ms         0.12%      12.227ms       4.667us          2620
#                                               aten::mul         0.80%     113.303ms         1.23%     174.601ms      12.397us        1.942s        19.44%        1.942s     137.909us         14084
#                                              aten::add_         0.68%      97.011ms         1.09%     154.972ms      10.880us        1.781s        17.82%        1.781s     125.004us         14244
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us      42.525ms         0.43%      42.525ms      95.777us           444
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us      69.959ms         0.70%      69.959ms      29.345us          2384
#                                               aten::sub         0.69%      97.610ms         0.80%     113.213ms      35.291us      44.056ms         0.44%      44.056ms      13.733us          3208
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us      30.027ms         0.30%      30.027ms      10.311us          2912
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us      24.735ms         0.25%      24.735ms      13.129us          1884
# void forward_kernel<float, float, float, int, (Activ...         0.00%       0.000us         0.00%       0.000us       0.000us      29.368ms         0.29%      29.368ms     407.889us            72
# void implicit_convolve_sgemm<float, float, 1024, 5, ...         0.00%       0.000us         0.00%       0.000us       0.000us       1.076ms         0.01%       1.076ms     269.000us             4
# void cudnn::winograd::generateWinogradTilesKernel<0,...         0.00%       0.000us         0.00%       0.000us       0.000us      46.000us         0.00%      46.000us       2.875us            16
# ampere_scudnn_winograd_128x128_ldg1_ldg4_relu_tile14...         0.00%       0.000us         0.00%       0.000us       0.000us       1.440ms         0.01%       1.440ms      90.000us            16
#                                   cudaFuncGetAttributes         0.00%      28.000us         0.00%      28.000us       1.750us       0.000us         0.00%       0.000us       0.000us            16
#                                    cudaFuncSetAttribute         0.00%     261.000us         0.00%     261.000us       0.012us       0.000us         0.00%       0.000us       0.000us         21071
# void cudnn::ops::nchwToNhwcKernel<float, float, floa...         0.00%       0.000us         0.00%       0.000us       0.000us       8.456ms         0.08%       8.456ms     132.125us            64
# void cutlass_cudnn::Kernel<cutlass_tensorop_s1688fpr...         0.00%       0.000us         0.00%       0.000us       0.000us     476.000us         0.00%     476.000us     119.000us             4
# void cudnn::ops::nhwcToNchwKernel<float, float, floa...         0.00%       0.000us         0.00%       0.000us       0.000us     178.000us         0.00%     178.000us      14.833us            12
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us        1.813s        18.15%        1.813s     112.366us         16136
#                                          aten::linspace         0.02%       2.875ms         0.07%       9.385ms      17.002us     309.000us         0.00%     618.000us       1.120us           552
# void (anonymous namespace)::elementwise_kernel_with_...         0.00%       0.000us         0.00%       0.000us       0.000us     309.000us         0.00%     309.000us       1.120us           276
#                                              aten::rsub         0.03%       4.018ms         0.11%      15.624ms      20.238us       0.000us         0.00%       2.053ms       2.659us           772
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us       2.053ms         0.02%       2.053ms       2.659us           772
#                                   aten::constant_pad_nd         0.00%      57.000us         0.00%     240.000us      60.000us       0.000us         0.00%      54.000us      13.500us             4
# void at::native::vectorized_elementwise_kernel<4, at...         0.00%       0.000us         0.00%       0.000us       0.000us     537.000us         0.01%     537.000us       1.974us           272
# void at::native::unrolled_elementwise_kernel<at::nat...         0.00%       0.000us         0.00%       0.000us       0.000us     276.277ms         2.77%     276.277ms      41.186us          6708
#                               aten::upsample_bilinear2d         0.00%     102.000us         0.02%       3.222ms     805.500us      48.000us         0.00%      48.000us      12.000us             4
# void at::native::(anonymous namespace)::upsample_bil...         0.00%       0.000us         0.00%       0.000us       0.000us      48.000us         0.00%      48.000us      12.000us             4
#                                            aten::expand         0.02%       3.029ms         0.03%       3.581ms       4.164us       0.000us         0.00%       0.000us       0.000us           860
#                                            aten::repeat         0.00%     303.000us         0.05%       7.590ms     379.500us       0.000us         0.00%       3.569ms     178.450us            20
#                                             aten::alias         0.00%      17.000us         0.00%      17.000us       0.850us       0.000us         0.00%       0.000us       0.000us            20
#                                            aten::unfold         0.00%     136.000us         0.00%     182.000us       2.395us       0.000us         0.00%       0.000us       0.000us            76
# -------------------------------------------------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------  ------------
# Self CPU time total: 14.224s
# Self CUDA time total: 9.991s

# %% [markdown]
# ## rendering novel views with fixed 3 source views

# %%
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate([1,8,21,103,114]):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    cmd = f'--datadir /mnt/data/new_disk/sungx/data/mvs_dataset/DTU/mvs_training/dtu/scan{scene}  \
    --dataset_name dtu_ft  \
    --ckpt ./ckpts//mvsnerf-v0.tar'

    args = config_parser(cmd.split())
    args.use_viewdirs = True

    args.N_samples = 128
    args.feat_dim =  8+3*4

    # create models
    if 0==i_scene:
        render_kwargs_train, render_kwargs_test, start, grad_vars = create_nerf_mvs(args, use_mvs=True, dir_embedder=False, pts_embedder=True)
        filter_keys(render_kwargs_train)

        MVSNet = render_kwargs_train['network_mvs']
        render_kwargs_train.pop('network_mvs')


    datadir = args.datadir
    datatype = 'val'
    pad = 24
    args.chunk = 5120


    print('============> rendering dataset <===================')
    dataset = dataset_dict[args.dataset_name](args, split=datatype)
    val_idx = dataset.img_idx
    
    save_as_image = True
    save_dir = f'results/test3'
    os.makedirs(save_dir, exist_ok=True)
    MVSNet.train()
    MVSNet = MVSNet.cuda()
    
    with torch.no_grad():

        imgs_source, proj_mats, near_far_source, pose_source = dataset.read_source_views(device=device)
        volume_feature, _, _ = MVSNet(imgs_source, proj_mats, near_far_source, pad=pad)
        imgs_source = unpreprocess(imgs_source)

        try:
            tqdm._instances.clear() 
        except Exception:     
            pass
        
        for i, batch in enumerate(tqdm(dataset)):
            torch.cuda.empty_cache()
            
            rays, img = decode_batch(batch)
            rays = rays.squeeze().to(device)  # (H*W, 3)
            img = img.squeeze().cpu().numpy()  # (H, W, 3)
            depth = batch['depth'].squeeze().numpy()  # (H, W)
        
            N_rays_all = rays.shape[0]
            rgb_rays, depth_rays_preds = [],[]
            for chunk_idx in range(N_rays_all//args.chunk + int(N_rays_all%args.chunk>0)):

                xyz_coarse_sampled, rays_o, rays_d, z_vals = ray_marcher(rays[chunk_idx*args.chunk:(chunk_idx+1)*args.chunk],
                                                    N_samples=args.N_samples)

                # Converting world coordinate to ndc coordinate
                H, W = img.shape[:2]
                inv_scale = torch.tensor([W - 1, H - 1]).to(device)
                w2c_ref, intrinsic_ref = pose_source['w2cs'][0], pose_source['intrinsics'][0].clone()
                xyz_NDC = get_ndc_coordinate(w2c_ref, intrinsic_ref, xyz_coarse_sampled, inv_scale,
                                             near=near_far_source[0], far=near_far_source[1], pad=pad*args.imgScale_test)


                # rendering
                rgb, disp, acc, depth_pred, alpha, extras = rendering(args, pose_source, xyz_coarse_sampled,
                                                                       xyz_NDC, z_vals, rays_o, rays_d,
                                                                       volume_feature,imgs_source, **render_kwargs_train)
    
                
                rgb, depth_pred = torch.clamp(rgb.cpu(),0,1.0).numpy(), depth_pred.cpu().numpy()
                rgb_rays.append(rgb)
                depth_rays_preds.append(depth_pred)

            
            depth_rays_preds = np.concatenate(depth_rays_preds).reshape(H, W)
            depth_rays_preds, _ = visualize_depth_numpy(depth_rays_preds, near_far_source)
            
            rgb_rays = np.concatenate(rgb_rays).reshape(H, W, 3)
            img_vis = np.concatenate((img*255,rgb_rays*255,depth_rays_preds),axis=1)
            
            if save_as_image:
                imageio.imwrite(f'{save_dir}/scan{scene}_{val_idx[i]:03d}.png', img_vis.astype('uint8'))
            else:
                rgbs.append(img_vis.astype('uint8'))
                
            # quantity
            # mask background since they are outside the far boundle
            mask = depth==0
            imageio.imwrite(f'{save_dir}/scan{scene}_{val_idx[i]:03d}_mask.png', mask.astype('uint8')*255)
            rgb_rays[mask],img[mask] = 0.0,0.0
            psnr.append( mse2psnr(np.mean((rgb_rays[~mask]-img[~mask])**2)))
            ssim.append( structural_similarity(rgb_rays, img, multichannel=True))
            
            img_tensor = torch.from_numpy(rgb_rays)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
            img_gt_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0
            LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

        print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
        psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)

    if not save_as_image:
        imageio.mimwrite(f'{save_dir}/{scene}_spiral.mp4', np.stack(rgbs), fps=20, quality=10)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')

# %% [markdown]
# # Pairs generation

# %%
import json,torch
import sys,os
import numpy as np
root = '/home/hengfei/Desktop/research/mvsnerf'
os.chdir(root)
sys.path.append(root)
pairs = torch.load('./configs/pairs.th')

# llff
root_dir = '/home/hengfei/Desktop/research/mvsnerf/xgaze/'
for scene in ['xgaze_11images_cropped_colmapCODE']:#
    poses_bounds = np.load(os.path.join(root_dir, scene, 'poses_bounds.npy'))  # (N_images, 11)
    poses = poses_bounds[:, :15].reshape(-1, 3, 5)  # (N_images, 3, 5)
    poses = np.concatenate([poses[..., 1:2], - poses[..., :1], poses[..., 2:4]], -1)

    ref_position = np.mean(poses[..., 3],axis=0, keepdims=True)
    dist = np.sum(np.abs(poses[..., 3] - ref_position), axis=-1)
    pair_idx = np.argsort(dist)[:11]
#     pair_idx = torch.randperm(len(poses))[:20].tolist()

    pairs[f'{scene}_test'] = pair_idx[::6]
    pairs[f'{scene}_val'] = pair_idx[::6]
    pairs[f'{scene}_train'] = np.delete(pair_idx, range(0,11,6))

torch.save(pairs,'/home/hengfei/Desktop/research/mvsnerf/configs/pairs.th')

# %% [markdown]
# # nerf

# %%
root = '/mnt/new_disk_2/anpei/code/nerf/logs/'
root_gt = '/mnt/new_disk2/anpei/code/MVS-NeRF/runs_fine_tuning/'
pairs = torch.load('/mnt/new_disk_2/anpei/code/MVS-NeRF/configs/pairs.th')
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['chair','drums','ficus','hotdog','lego','materials','mic','ship']):#
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/{scene}_test/testset_200000/*.png'))
    for j, file in enumerate(files):

        idx = pairs[f'{scene}_val'][j]
        img = cv2.imread(file)[...,::-1]
        gt = cv2.imread(f'{root_gt}/{scene}/{scene}/{scene}_00009999_{j:02d}.png')[...,::-1]
        gt, img = gt[:,:800].astype('float')/255.0, img.astype('float')/255.0

#         H_crop, W_crop = np.array(gt.shape[:2])//10
#         img = img[H_crop:-H_crop,W_crop:-W_crop]
#         gt = gt[H_crop:-H_crop,W_crop:-W_crop]

        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['fern','flower','fortress','horns','leaves', 'orchids', 'room',  'trex']):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/{scene}_test/testset_200000/*.png'))
    for j, file in enumerate(files):

        idx = pairs[f'{scene}_val'][j]
        img = cv2.resize(cv2.imread(file)[...,::-1],(960,640))
        gt =  cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/{scene}_{idx:03d}.png')[...,::-1]
        gt, img = gt[:,:960].astype('float')/255.0, img.astype('float')/255.0


        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate([1,8,21,103,114]):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/scan{scene}_test/testset_200000/*.png'))
    for j, file in enumerate(files):

        idx = pairs[f'dtu_val'][j]
        img = cv2.imread(file)[...,::-1]
        gt = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}.png')[...,::-1]
        mask = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}_mask.png')==255
        gt, img = gt[:,:640].astype('float')/255.0, img.astype('float')/255.0

        gt[mask],img[mask] = 0.0,0.0
        psnr.append( mse2psnr(np.mean((gt[~mask]-img[~mask])**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')
# Out:
# =====> scene: chair mean psnr 31.070870959993407 ssim: 0.970869913728838 lpips: 0.05512496456503868
# =====> scene: drums mean psnr 25.464383523724557 ssim: 0.9430287321705997 lpips: 0.1010842639952898
# =====> scene: ficus mean psnr 29.72717081186501 ssim: 0.9688198661712594 lpips: 0.04721927270293236
# =====> scene: hotdog mean psnr 34.63162021512352 ssim: 0.9798700143526428 lpips: 0.0885334312915802
# =====> scene: lego mean psnr 32.65761069614622 ssim: 0.9751430050524844 lpips: 0.05375238787382841
# =====> scene: materials mean psnr 30.220202654922936 ssim: 0.9677394226502894 lpips: 0.1052329633384943
# =====> scene: mic mean psnr 31.810551677509977 ssim: 0.9810118386928188 lpips: 0.03268271638080478
# =====> scene: ship mean psnr 29.487980342358682 ssim: 0.9079920156014059 lpips: 0.2625834122300148
# =====> all mean psnr 30.633798860205538 ssim: 0.9618093510525423 lpips: 0.09327667654724792
# =====> scene: fern mean psnr 23.87081932481545 ssim: 0.828319405500272 lpips: 0.29106350988149643
# =====> scene: flower mean psnr 26.84248375485232 ssim: 0.8972176342834637 lpips: 0.175886869430542
# =====> scene: fortress mean psnr 31.368287455491632 ssim: 0.9454387223441942 lpips: 0.14687807857990265
# =====> scene: horns mean psnr 25.957297279910254 ssim: 0.9002932801372645 lpips: 0.24746065214276314
# =====> scene: leaves mean psnr 21.209230306630403 ssim: 0.7924383925048237 lpips: 0.3013022392988205
# =====> scene: orchids mean psnr 19.805083676014405 ssim: 0.7216119459229409 lpips: 0.3210122361779213
# =====> scene: room mean psnr 33.538893189163886 ssim: 0.9782926576909046 lpips: 0.15664737671613693
# =====> scene: trex mean psnr 25.191124840989897 ssim: 0.8986906362165991 lpips: 0.24522138014435768
# =====> all mean psnr 25.972902478483533 ssim: 0.8702878343250579 lpips: 0.23568404279649258
# =====> scene: 1 mean psnr 26.621467948629075 ssim: 0.9015109955368615 lpips: 0.26542308926582336
# =====> scene: 8 mean psnr 28.331380911917446 ssim: 0.8758834032089559 lpips: 0.32112571597099304
# =====> scene: 21 mean psnr 23.238617049537122 ssim: 0.8736486067576469 lpips: 0.2456555962562561
# =====> scene: 103 mean psnr 30.40125554666663 ssim: 0.9442875531229784 lpips: 0.25619567558169365
# =====> scene: 114 mean psnr 26.46890004323232 ssim: 0.9134870027630088 lpips: 0.2253187969326973
# =====> all mean psnr 27.01232429999652 ssim: 0.9017635122778904 lpips: 0.2627437748014927

# %% [markdown]
# # ours

# %%
root = '/mnt/new_disk2/anpei/code/MVS-NeRF/runs_fine_tuning/'
pairs = torch.load('/mnt/new_disk_2/anpei/code/MVS-NeRF/configs/pairs.th')
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['chair','drums','ficus','hotdog','lego','materials','mic','ship']):
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/{scene}/{scene}/{scene}_00009999_*'))
    for j, file in enumerate(files):

        idx = pairs[f'{scene}_val'][j]
        img = cv2.imread(file).astype('float')[...,::-1]
        gt, img = img[:,:800]/255.0, img[:,800:1600]/255.0

#         H_crop, W_crop = np.array(gt.shape[:2])//10
#         img = img[H_crop:-H_crop,W_crop:-W_crop]
#         gt = gt[H_crop:-H_crop,W_crop:-W_crop]

        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['fern','flower','fortress','horns','leaves', 'orchids', 'room',  'trex']):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'/mnt/new_disk2/anpei/code/MVS-NeRF/runs_fine_tuning/{scene}/{scene}/{scene}_00009999_*'))
    for j, file in enumerate(files):

        idx = pairs[f'{scene}_val'][j]
        img = cv2.imread(file)[...,::-1]
        gt, img = img[:,:960].astype('float')/255.0, img[:,960:960*2].astype('float')/255.0

        H_crop, W_crop = np.array(gt.shape[:2])//10
        img = img[H_crop:-H_crop,W_crop:-W_crop]
        gt = gt[H_crop:-H_crop,W_crop:-W_crop]


        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

root = '/mnt/new_disk2/anpei/code/MVS-NeRF/runs_fine_tuning/'
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate([1,8,21,103,114]):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/dtu_scan{scene}_1h/dtu_scan{scene}_1h/00010239_*'))
    for j, file in enumerate(files):

        idx = pairs[f'dtu_val'][j]
        img = cv2.imread(file)[...,::-1][:,640:1280]
        gt = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}.png')[...,::-1]
        mask = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}_mask.png')==255
        gt, img = gt[:,:640].astype('float')/255.0, img.astype('float')/255.0

        gt[mask],img[mask] = 0.0,0.0
        psnr.append( mse2psnr(np.mean((gt[~mask]-img[~mask])**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')
# Out:
# =====> scene: chair mean psnr 26.746873810513947 ssim: 0.9321234340308168 lpips: 0.15475058555603027
# =====> scene: drums mean psnr 22.28406117543553 ssim: 0.8964614019632969 lpips: 0.21542910858988762
# =====> scene: ficus mean psnr 26.365789669973488 ssim: 0.9438413276712496 lpips: 0.15914445742964745
# =====> scene: hotdog mean psnr 32.489636248742805 ssim: 0.9699785599978382 lpips: 0.11295554973185062
# =====> scene: lego mean psnr 26.79832336361502 ssim: 0.9245065827858229 lpips: 0.18708691000938416
# =====> scene: materials mean psnr 24.957611270986945 ssim: 0.9249186604651752 lpips: 0.1740873008966446
# =====> scene: mic mean psnr 29.449610622444368 ssim: 0.9693072200690339 lpips: 0.092950988560915
# =====> scene: ship mean psnr 26.60832366062154 ssim: 0.8780999869891254 lpips: 0.28621142730116844
# =====> all mean psnr 26.962528727791707 ssim: 0.9299046467465449 lpips: 0.17282704100944102
# =====> scene: fern mean psnr 22.61357364768159 ssim: 0.77000724312094 lpips: 0.2827577739953995
# =====> scene: flower mean psnr 25.52052448547126 ssim: 0.8816617628340061 lpips: 0.19497620686888695
# =====> scene: fortress mean psnr 28.010539767191638 ssim: 0.8958878940094137 lpips: 0.19440287351608276
# =====> scene: horns mean psnr 24.99889079936664 ssim: 0.8806854873247154 lpips: 0.2329558990895748
# =====> scene: leaves mean psnr 21.228759476443667 ssim: 0.8063488185998933 lpips: 0.24219803884625435
# =====> scene: orchids mean psnr 19.460068266904813 ssim: 0.7087825176683923 lpips: 0.3091204948723316
# =====> scene: room mean psnr 29.150237317214977 ssim: 0.9570667630128395 lpips: 0.16276488453149796
# =====> scene: trex mean psnr 24.079128145103503 ssim: 0.8873396265555692 lpips: 0.2028873674571514
# =====> all mean psnr 24.38271523817226 ssim: 0.8484725141407212 lpips: 0.22775794239714742
# =====> scene: 1 mean psnr 28.046498782015014 ssim: 0.9341022735743112 lpips: 0.17119702696800232
# =====> scene: 8 mean psnr 28.875841987497292 ssim: 0.8999499891440654 lpips: 0.26092011481523514
# =====> scene: 21 mean psnr 24.870061827644722 ssim: 0.9215085855864712 lpips: 0.14212623238563538
# =====> scene: 103 mean psnr 32.226849694259215 ssim: 0.9638182025610383 lpips: 0.16953438520431519
# =====> scene: 114 mean psnr 28.46625266665073 ssim: 0.9451965364044997 lpips: 0.15322893112897873
# =====> all mean psnr 28.497100991613394 ssim: 0.9329151174540771 lpips: 0.17940133810043335

# %% [markdown]
# # ibrnet

# %%
# root = '/mnt/new_disk2/anpei/code/IBRNet/logs'
pairs = torch.load('/mnt/new_disk_2/anpei/code/MVS-NeRF/configs/pairs.th')
# psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
# for i_scene, scene in enumerate(['chair','drums','ficus','hotdog','lego','materials','mic','ship']):#,
#     psnr,ssim,LPIPS_vgg = [],[],[]
    
#     files = sorted(glob.glob(f'{root}/nerf-3view-finetuning-nearest-{scene}/010000_*'))
#     for j, file in enumerate(files):

#         idx = pairs[f'{scene}_val'][j]
#         img = cv2.imread(file).astype('float')[...,::-1]
#         gt, img = img[:,800:800*2]/255.0, img[:,800*3:800*4]/255.0

# #         H_crop, W_crop = np.array(gt.shape[:2])//10
# #         img = img[H_crop:-H_crop,W_crop:-W_crop]
# #         gt = gt[H_crop:-H_crop,W_crop:-W_crop]

#         psnr.append( mse2psnr(np.mean((gt-img)**2)))
#         ssim.append( structural_similarity(gt, img, multichannel=True))

#         img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
#         img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
#         LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

#     print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
#     psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
# print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['fern','flower','fortress','horns','leaves', 'orchids', 'room',  'trex']):#
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'/mnt/new_disk2/anpei/code/IBRNet/logs/llff-3view-finetuning-nearest-{scene}/010000_*'))
    for j, file in enumerate(files):

        idx = pairs[f'{scene}_val'][j]
        img = cv2.imread(file)[...,::-1]
        gt, img = img[:,1008:1008*2].astype('float')/255.0, img[:,1008*3:1008*4].astype('float')/255.0
        img, gt = cv2.resize(img,(960,640)), cv2.resize(gt,(960,640))

        H_crop, W_crop = np.array(gt.shape[:2])//10
        img = img[H_crop:-H_crop,W_crop:-W_crop]
        gt = gt[H_crop:-H_crop,W_crop:-W_crop]

        
        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

root = '/mnt/new_disk2/anpei/code/IBRNet/logs'
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate([1,8,21,103,114]):#
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    files = sorted(glob.glob(f'{root}/dtu-3view-finetuning-nearest-scan{scene}/010000_*'))
    for j, file in enumerate(files):

        idx = pairs[f'dtu_val'][j]
        img = cv2.imread(file)[...,::-1][:,3*640:4*640]
        gt = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}.png')[...,::-1]
        mask = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}_mask.png')==255
        gt, img = gt[:,:640].astype('float')/255.0, img.astype('float')/255.0

        gt[mask],img[mask] = 0.0,0.0
        psnr.append( mse2psnr(np.mean((gt[~mask]-img[~mask])**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')
# Out:
# =====> scene: fern mean psnr 22.64474646040451 ssim: 0.7736232480476191 lpips: 0.26588304713368416
# =====> scene: flower mean psnr 26.553349019087786 ssim: 0.9092690161984827 lpips: 0.14575103670358658
# =====> scene: fortress mean psnr 30.338842953903075 ssim: 0.9368867837660259 lpips: 0.13289865292608738
# =====> scene: horns mean psnr 25.01290939681414 ssim: 0.9040335882553917 lpips: 0.1899307444691658
# =====> scene: leaves mean psnr 22.076508076698556 ssim: 0.8430354849586478 lpips: 0.17987846583127975
# =====> scene: orchids mean psnr 19.007830032899616 ssim: 0.7045611776629173 lpips: 0.2861044891178608
# =====> scene: room mean psnr 31.05473820815669 ssim: 0.9723299877991765 lpips: 0.08911459799855947
# =====> scene: trex mean psnr 22.339864946223464 ssim: 0.8421255627008343 lpips: 0.22207806631922722
# =====> all mean psnr 24.878598636773482 ssim: 0.8607331061736369 lpips: 0.1889548875624314
# =====> scene: 1 mean psnr 30.99564992655386 ssim: 0.9548394719193786 lpips: 0.1285402663052082
# =====> scene: 8 mean psnr 32.46173840309124 ssim: 0.9445782574823819 lpips: 0.16979694738984108
# =====> scene: 21 mean psnr 27.88178725277648 ssim: 0.9467770144187784 lpips: 0.1040295660495758
# =====> scene: 103 mean psnr 34.399916992709706 ssim: 0.9675776122666799 lpips: 0.15563546121120453
# =====> scene: 114 mean psnr 31.00119644953211 ssim: 0.9638488318305859 lpips: 0.09874588809907436
# =====> all mean psnr 31.348057804932676 ssim: 0.955524237583561 lpips: 0.1313496258109808

# %% [markdown]
# # pixel nerf

# %%
root = '/mnt/new_disk2/anpei/code/pixel-nerf/visuals/dtu'
root_gt = '/mnt/new_disk2/anpei/code/MVS-NeRF/runs_fine_tuning/'
pairs = torch.load('/mnt/new_disk_2/anpei/code/MVS-NeRF/configs/pairs.th')
psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['chair','drums','ficus','hotdog','lego','materials','mic','ship']):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    pairs_idx = pairs[f'{scene}_val']
    for j, file in enumerate(pairs_idx):

        idx = pairs_idx[j]
        img = cv2.imread(f'{root}/{scene}_{idx:03d}.png')[...,::-1]
        gt = cv2.imread(f'{root_gt}/{scene}/{scene}/{scene}_00009999_{j:02d}.png')[...,::-1]
        gt, img = gt[:,:800].astype('float')/255.0, img.astype('float')/255.0

#         H_crop, W_crop = np.array(gt.shape[:2])//10
#         img = img[H_crop:-H_crop,W_crop:-W_crop]
#         gt = gt[H_crop:-H_crop,W_crop:-W_crop]

        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all = [],[],[]
for i_scene, scene in enumerate(['fern','flower','fortress','horns','leaves', 'orchids', 'room',  'trex']):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    pairs_idx = pairs[f'{scene}_val']
    for j, file in enumerate(pairs_idx):

        idx = pairs_idx[j]
        img = cv2.resize(cv2.imread(f'{root}/{scene}_{idx:03d}.png')[...,::-1],(960,640))
        gt =  cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/{scene}_{idx:03d}.png')[...,::-1]
        gt, img = gt[:,:960].astype('float')/255.0, img.astype('float')/255.0


        psnr.append( mse2psnr(np.mean((gt-img)**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}') 

psnr_all,ssim_all,LPIPS_vgg_all,depth_acc = [],[],[],[]
for i_scene, scene in enumerate([1,8,21,103,114]):#,
    psnr,ssim,LPIPS_vgg = [],[],[]
    
    pairs_idx = pairs[f'dtu_val']
    for j, file in enumerate(pairs_idx):

        idx = pairs_idx[j]
        img = cv2.imread(f'{root}/scan{scene}_{idx:03d}.png')[...,::-1]
        
        gt = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}.png')[...,::-1]
        mask = cv2.imread(f'/mnt/new_disk2/anpei/code/MVS-NeRF/results/test3/scan{scene}_{idx:03d}_mask.png')==255
        gt, img = gt[:,:640].astype('float')/255.0, img.astype('float')/255.0

        gt[mask],img[mask] = 0.0,0.0
        psnr.append( mse2psnr(np.mean((gt[~mask]-img[~mask])**2)))
        ssim.append( structural_similarity(gt, img, multichannel=True))

        img_tensor = torch.from_numpy(img)[None].permute(0,3,1,2).float()*2-1.0 # image should be RGB, IMPORTANT: normalized to [-1,1]
        img_gt_tensor = torch.from_numpy(gt)[None].permute(0,3,1,2).float()*2-1.0
        LPIPS_vgg.append( loss_fn_vgg(img_tensor, img_gt_tensor).item())
        
        # depth
#         depth_pred = torch.load(f'{root}/scan{scene}_{idx:03d}_depth.th')
#         depth_gt,_ =  read_depth(f'/mnt/data/new_disk/sungx/data/mvs_dataset/DTU/mvs_training/dtu/Depths/scan{scene}/depth_map_{idx:04d}.pfm')
        
#         mask_gt = depth_gt>0
#         abs_err = abs_error(depth_pred*1.5, depth_gt/200, mask_gt).numpy()

#         eval_metric = [0.01,0.05, 0.1]
#         depth_acc[f'abs_err'][f'{scene}'] = np.mean(abs_err)
#         depth_acc[f'acc_l_{eval_metric[0]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[0]).mean()
#         depth_acc[f'acc_l_{eval_metric[1]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[1]).mean()
#         depth_acc[f'acc_l_{eval_metric[2]}'][f'{scene}'] = acc_threshold(abs_err,eval_metric[2]).mean()

    print(f'=====> scene: {scene} mean psnr {np.mean(psnr)} ssim: {np.mean(ssim)} lpips: {np.mean(LPIPS_vgg)}')   
    psnr_all.append(psnr);ssim_all.append(ssim);LPIPS_vgg_all.append(LPIPS_vgg)
print(f'=====> all mean psnr {np.mean(psnr_all)} ssim: {np.mean(ssim_all)} lpips: {np.mean(LPIPS_vgg_all)}')
# Out:
# =====> scene: chair mean psnr 7.175962813343725 ssim: 0.6243642351905847 lpips: 0.38591109961271286
# =====> scene: drums mean psnr 8.148548711878252 ssim: 0.6701584468514097 lpips: 0.42121122032403946
# =====> scene: ficus mean psnr 6.608732738834844 ssim: 0.668716265099144 lpips: 0.3350602239370346
# =====> scene: hotdog mean psnr 6.799387670799135 ssim: 0.6689815218041557 lpips: 0.43327029794454575
# =====> scene: lego mean psnr 7.740217521658803 ssim: 0.6710903029993184 lpips: 0.42670799791812897
# =====> scene: materials mean psnr 7.609290420358684 ssim: 0.6441046576733512 lpips: 0.43245941400527954
# =====> scene: mic mean psnr 7.707203698223274 ssim: 0.7294597852809476 lpips: 0.32929887622594833
# =====> scene: ship mean psnr 7.295484760785579 ssim: 0.5836685948507447 lpips: 0.5257005095481873
# =====> all mean psnr 7.385603541985287 ssim: 0.657567976218707 lpips: 0.4112024549394846
# =====> scene: fern mean psnr 12.397648684821284 ssim: 0.5312397318110376 lpips: 0.6500117480754852
# =====> scene: flower mean psnr 9.99675489427281 ssim: 0.43323656344453193 lpips: 0.7075561136007309
# =====> scene: fortress mean psnr 14.073488262986546 ssim: 0.6736649368929569 lpips: 0.6075489073991776
# =====> scene: horns mean psnr 11.71002161685521 ssim: 0.5157559834106309 lpips: 0.705190509557724
# =====> scene: leaves mean psnr 9.847068575637605 ssim: 0.2681360856716045 lpips: 0.6947661340236664
# =====> scene: orchids mean psnr 9.624184850140201 ssim: 0.3168018322171233 lpips: 0.7207814902067184
# =====> scene: room mean psnr 11.750716240417157 ssim: 0.6906632306577324 lpips: 0.6112178564071655
# =====> scene: trex mean psnr 10.55211637013632 ssim: 0.45770187915676297 lpips: 0.6672322899103165
# =====> all mean psnr 11.243999936908391 ssim: 0.48590003040779756 lpips: 0.6705381311476231
# =====> scene: 1 mean psnr 21.64330896303546 ssim: 0.8268906240371169 lpips: 0.3728666678071022
# =====> scene: 8 mean psnr 23.69860813191727 ssim: 0.8291247579664462 lpips: 0.38369619846343994
# =====> scene: 21 mean psnr 16.03916045790063 ssim: 0.6905614284959526 lpips: 0.4074021577835083
# =====> scene: 103 mean psnr 16.75554527345504 ssim: 0.8356182752116726 lpips: 0.3762983977794647
# =====> scene: 114 mean psnr 18.403335481905653 ssim: 0.7632868039029544 lpips: 0.371926873922348
# =====> all mean psnr 19.30799166164281 ssim: 0.7890963779228286 lpips: 0.3824380591511726
